# %% [markdown]
# <a href="https://colab.research.google.com/github/OWL-408/CIT2024/blob/main/%E3%82%B0%E3%83%A9%E3%83%95%E4%BD%9C%E6%88%90%E7%94%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 代表4鋼の応力ひずみ曲線

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/TS-εTS/F.csv',
    '/content/drive/MyDrive/program/TS-εTS/F-P.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/B.csv',
    '/content/drive/MyDrive/program/TS-εTS/M.csv'

]

# カスタムラベルのリスト
custom_labels = ['F', 'F-P', 'B','M']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# これより各種材料比較の結果(LSTM)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program_LSTM/output-data_forecast_LSTM_only/F_forecast_only.csv',
    '/content/drive/MyDrive/program/TS-εTS/F.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/F鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['F-LSTM', 'F-Actual1', 'F-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_210.csv',
    '/content/drive/MyDrive/program/TS-εTS/F.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/F鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['F-Generate', 'F-Actual1', 'F-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_400.csv',
    '/content/drive/MyDrive/program/TS-εTS/F-P.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/F+P鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['F-P-Generate', 'F-P-Actual1', 'F-P-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_850.csv',
    '/content/drive/MyDrive/program/TS-εTS/B.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/B鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['B-Generate', 'B-Actual1', 'B-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_1230.csv',
    '/content/drive/MyDrive/program/TS-εTS/M.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/M鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['M-Generate', 'M-Actual1', 'M-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# base

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by1&α/waveform_TS_210.csv',
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_210.csv',
    '/content/drive/MyDrive/program_LSTM/output-data_forecast_LSTM_only/F_forecast_only.csv',
    '/content/drive/MyDrive/program/TS-εTS/F.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/F鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS210-Generate','TS210-Gen_train-Augmentation','F-LSTM', 'F-Actual1', 'F-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    #plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by1&α/waveform_TS_400.csv',
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_400.csv',
    '/content/drive/MyDrive/program_LSTM/output-data_forecast_LSTM_only/F-P_forecast_only.csv',
    '/content/drive/MyDrive/program/TS-εTS/F-P.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/F+P鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS400-Generate','TS400-Gen_train-Augmentation','F-P-LSTM', 'F-P-Actual1', 'F-P-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by1&α/waveform_TS_850.csv',
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_850.csv',
    '/content/drive/MyDrive/program_LSTM/output-data_forecast_LSTM_only/B_forecast_only.csv',
    '/content/drive/MyDrive/program/TS-εTS/B.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/B鋼_2.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS850-Generate','TS850-Gen_train-Augmentation','B-LSTM', 'B-Actual1', 'B-Actual2']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_lower_limit=-20):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)

        # y軸の下限を -50 に設定し、上限は自動設定
    plt.ylim(bottom=y_lower_limit)

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by1&α/waveform_TS_1230.csv',
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_1230.csv',
    '/content/drive/MyDrive/program_LSTM/output-data_forecast_LSTM_only/M_forecast_only.csv',
    '/content/drive/MyDrive/program/TS-εTS/M.csv' ,
    '/content/drive/MyDrive/program/TS-εTS/M鋼_2.csv'
]

# カスタムラベルのリスト1
custom_labels = ['TS1230-Generate','TS1230-Gen_train-Augmentation','M-LSTM', 'M-Actual1', 'M-Actual2']

# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# DP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_500.csv',
    '/content/drive/MyDrive/program4/00検証用データtest_DP/500DP_VM4C.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS500DP-Generate', '500DP_VM4C-test']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_538.csv',
    '/content/drive/MyDrive/program4/00検証用データtest_DP/540DP_VM4F.csv',
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_546.csv',
    '/content/drive/MyDrive/program4/00学習用データtrain_DP/540DP_VM13C.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS538DP-Generate', '540DP_VM4F-test', 'TS546DP-Generate', '540DP_VM13C-train']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_600.csv',
    '/content/drive/MyDrive/program4/00学習用データtrain_DP/600DP_VM13F.csv',
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_607.csv',
    '/content/drive/MyDrive/program4/00検証用データtest_DP/590DP.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS600DP-Generate', '600DP-train', 'TS607DP-Generate','590DP-test']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_700.csv',
    '/content/drive/MyDrive/program4/00学習用データtrain_DP/700DP_VM20F.csv',
    '/content/drive/MyDrive/program4/00検証用データtest_DP/700DP_VM30.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS700DP-Generate', '700DP_VM20F-train', '700DP_VM30-test']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_770.csv',
    '/content/drive/MyDrive/program4/00学習用データtrain_DP/780DP_VM20C.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS770DP-Generate','780DP_VM20-train']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_907.csv',
    '/content/drive/MyDrive/program4/00検証用データtest_DP/900DP_VM68.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS907DP-Generate','900DP_VM68-test']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_1190.csv',
    '/content/drive/MyDrive/program4/00学習用データtrain_DP/1180DP.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS1190DP-Generate', '1180DP-train']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
#   SWift式

# %% [markdown]
# 確認

# %%
#check

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by2&α/waveform_TS_800.csv',
    '/content/drive/MyDrive/program/waveform_outputs_DP_only-train/waveform-DP_TS_800.csv',
    '/content/drive/MyDrive/program/waveform_outputs_DP/waveform-DP_TS_800.csv'
]

# カスタムラベルのリスト
custom_labels = ['TS800-Generate', 'TS800DP-Generate','TS800DP-Generate-trainbase']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from google.colab import drive

# Google Driveのマウント
drive.mount('/content/drive')

# 波形を可視化しCSV保存
def plot_and_save_waveforms(file_paths, target_length=100, custom_labels=None, x_limits=None, y_limits=None):
    # プロット設定
    title_font_size = 32
    label_font_size = 30
    legend_font_size = 27
    ticks_font_size = 24
    line_width = 2  # カスタム プロットラインの太さ
    legend_line_width = 4  # カスタム 凡例ラインの太さ

    plt.figure(figsize=(10, 8))

    for idx, file_path in enumerate(file_paths):
        # CSVファイルを読み込み
        df = pd.read_csv(file_path)
        Nominal_strain = df['Nominal strain']
        reconstructed_waveform = df['Nominal stress']

        # 重ねてプロット
        plt.plot(Nominal_strain, reconstructed_waveform, label=custom_labels[idx] if custom_labels else os.path.basename(file_path))

        # CSVの保存
        #filename = os.path.join('output_folder', f'waveform-{os.path.basename(file_path).split(".")[0]}.csv')
        #df.to_csv(filename, index=False)

    # 軸の範囲の設定
    if x_limits:
        plt.xlim(x_limits)
    if y_limits:
        plt.ylim(y_limits)

    plt.xlabel('Nominal Strain [-]', fontsize=label_font_size, labelpad=20)
    plt.ylabel('Nominal Stress [MPa]', fontsize=label_font_size)
    #plt.title('Generative Waveform', fontsize=title_font_size, pad=20)

    # 凡例
    legend_lines = [plt.Line2D([0], [0], color=line.get_color(), label=line.get_label(), linewidth=legend_line_width) for line in plt.gca().get_lines()]
    plt.legend(handles=legend_lines, fontsize=legend_font_size, loc='upper left', bbox_to_anchor=(1, 1.02))

    plt.xticks(fontsize=ticks_font_size)
    plt.yticks(fontsize=ticks_font_size)
    #plt.grid(True)
    plt.show()

# ファイルパスのリストとオプションの設定
csv_files = [
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_210.csv',
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by2/waveform_TS_210.csv',
    '/content/drive/MyDrive/program/waveform_outputs/waveform_TS_1230.csv',
    '/content/drive/MyDrive/program/waveform_outputs_base_train4by2/waveform_TS_1230.csv'

]

# カスタムラベルのリスト
custom_labels = ['210', 'test210', '1230','test1230']


# 実行
plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-ed6d1c44240d> in <cell line: 0>()
#      66
#      67 # 実行
# ---> 68 plot_and_save_waveforms(csv_files, custom_labels=custom_labels)
#
# <ipython-input-20-ed6d1c44240d> in plot_and_save_waveforms(file_paths, target_length, custom_labels, x_limits, y_limits)
#      22     for idx, file_path in enumerate(file_paths):
#      23         # CSVファイルを読み込み
# ---> 24         df = pd.read_csv(file_path)
#      25         Nominal_strain = df['Nominal strain']
#      26         reconstructed_waveform = df['Nominal stress']
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
